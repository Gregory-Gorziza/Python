# %% [markdown]
# <a href="https://colab.research.google.com/github/Gregory-Gorziza/Python/blob/main/Exerc%C3%ADcios_de_Revis%C3%A3o_do_M%C3%B3dulo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios de Revisão do Módulo 2

# %%
name = input("")
print("Olá,", name, "! É um prazer conhecê-lo(a).")
# Out:
# Gregory
# Olá, Gregory ! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print("Olá,", name, "! É um prazer conhecê-lo(a).")
# Out:
# Qual é o seu nome? Gregory
# Olá, Gregory ! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print(f"Olá, {name}! É um prazer conhecê-lo(a).")
# Out:
# Qual é o seu nome? Gregory
# Olá, Gregory! É um prazer conhecê-lo(a).
