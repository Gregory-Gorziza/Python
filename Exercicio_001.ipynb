# %% [markdown]
# <a href="https://colab.research.google.com/github/Gregory-Gorziza/Python/blob/main/Exercicio_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios de Revisão do Módulo 2

# %%
name = input("")
print("Olá,", name, "! É um prazer conhecê-lo(a).")
# Out:
# Gregory
# Olá, Gregory ! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print("Olá,", name, "! É um prazer conhecê-lo(a).")
# Out:
# Qual é o seu nome? Gregory
# Olá, Gregory ! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print(f"Olá, {name}! É um prazer conhecê-lo(a).")
# Out:
# Qual é o seu nome? Gregory
# Olá, Gregory! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print("Olá, {}! É um prazer conhecê-lo(a).".format(name))
# Out:
# Qual é o seu nome? Gregory
# Olá, Gregory! É um prazer conhecê-lo(a).

# %%
name = input("Qual é o seu nome? ")
print(f"Bom dia! Sr(a).{name}.")
# Out:
# Qual é o seu nome? Gregory
# Bom dia! Sr(a).Gregory.

# %%
name = input("Qual é o seu nome? ")
print(f"passar bem, {name}.")
# Out:
# Qual é o seu nome? Gregory
# passar bem, Gregory.

# %%
name = input("Qual é o seu nome? ")
saldação = input("Qual é a sua saldação? ")
print(f"{saldação}, {name}! tudo em cima.")
# Out:
# Qual é o seu nome? Gregory
# Qual é a sua saldação? Fala ia
# Fala ia, Gregory! tudo em cima.
